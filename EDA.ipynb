# %% [markdown]
# # **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#34495E;">Exploratory Data Analysis</span>**
#
#
#
# The goal is to perform exploratory data analysis to gain insights and understand the variables better. Additionally, I will design a professional data visualization that tells a story and aids in data-driven decision-making for business needs.

# %% [markdown]
# ## **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#34495E;">Purpose**
# **The purpose** of this project is to conduct exploratory data analysis on a provided data set, to continue the investigation began in [Inspect and Organize](https://github.com/quirozfm/TikTok-df/blob/main/Inspect%20and%20Organize.ipynb) and perform further EDA on this data with the aim of learning more about the variables. Of particular interest is information related to what distinguishes claim videos from opinion videos.
#
# #### **We will explore the dataset and create visualizations in 4 major parts withing our <span style="color:#2ECC71;">  Plan</span>, <span style="color:#FFFF00;">Analyze</span>,<span style="color:#3498DB;"> Construct</span>,<span style="color:#9B59B6;"> Execute</span> (<span style="color:#2ECC71;">P</span>, <span style="color:#FFC300;">A</span>, <span style="color:#3498DB;">C</span>, <span style="color:#9B59B6;">E</span>) </span> framework.**
# <br/>
#
# ## **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#34495E;">Outline**
# **Part 1:** <span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">Imports, links, and loading
#
# **Part 2:** <span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">Data Exploration
#
# **Part 3:** <span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">Build visualizations
#
# **Part 4:** <span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">Evaluate and share results
#
# <br/>
#
# ### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#2ECC71;"><span style="color:#2ECC71;">P</span><span style="color:#FFC300;">A</span><span style="color:#3498DB;">C</span><span style="color:#9B59B6;">E</span></span> : </span><span style="color:#2ECC71;">Plan**</span>

# %%
# Import packages for data manipulation
import pandas as pd
import numpy as np


# Import packages for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset into dataframe
data = pd.read_csv("F:/Files/tiktok_dataset.csv")

# %% [markdown]
# ### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#2ECC71;"><span style="color:#2ECC71;">P</span><span style="color:#FFC300;">A</span><span style="color:#3498DB;">C</span><span style="color:#9B59B6;">E</span></span> : </span><span style="color:#FFC300;">Analyze**</span>

# %%
# Display and examine the first few rows of the dataframe
data.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
# Get the size of the data
data.size
# Out:
# 232584

# %%
# Get the shape of the data
data.shape
# Out:
# (19382, 12)

# %%
# Get basic information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
# Generate a table of descriptive statistics
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [markdown]
# The visualizations most helpful for considering the distribution of the data include box plots and histograms. Visualizing the distribution of the data can inform the next steps and considerations in data analysis.The distribution will help guide which types of modeling is needed.

# %% [markdown]
# ### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#2ECC71;"><span style="color:#2ECC71;">P</span><span style="color:#FFC300;">A</span><span style="color:#3498DB;">C</span><span style="color:#9B59B6;">E</span></span> : </span><span style="color:#3498DB;">Construct**</span>

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">video_duration_sec**

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`
plt.figure(figsize=(5,1))
plt.title('video_duration_sec')
sns.boxplot(x=data['video_duration_sec']);

# %%
plt.figure(figsize=(5,3))
sns.histplot(data['video_duration_sec'], bins=range(0,61,5))
plt.title('Video duration histogram');

# %% [markdown]
#  All videos are 5-60 seconds in length, and the distribution is uniform.

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">video_view_count**

# %%
# Create a boxplot to visualize distribution of `video_view_count`
plt.figure(figsize=(5, 1))
plt.title('video_view_count')
sns.boxplot(x=data['video_view_count']);

# %%
plt.figure(figsize=(5,3))
sns.histplot(data['video_view_count'], bins=range(0,(10**6+1),10**5))
plt.title('Video view count histogram');

# %% [markdown]
# This variable has a very uneven distribution, with more than half the videos receiving fewer than 100,000 views. Distribution of view counts > 100,000 views is uniform.

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">video_like_count**

# %%
# Create a boxplot to visualize distribution of `video_like_count`
plt.figure(figsize=(10,1))
plt.title('video_like_count')
sns.boxplot(x=data['video_like_count']);

# %%
# plt.figure(figsize=(5,3))
ax = sns.histplot(data['video_like_count'], bins=range(0,(7*10**5+1),10**5))
labels = [0] + [str(i) + 'k' for i in range(100, 701, 100)]
ax.set_xticks(range(0,7*10**5+1,10**5), labels=labels)
plt.title('Video like count histogram');

# %% [markdown]
# Similar to view count, there are far more videos with < 100,000 likes than there are videos with more. However, in this case, there is more of a taper, as the data skews right, with many videos at the upper extremity of like count.

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">video_comment_count**

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
plt.figure(figsize=(5,1))
plt.title('video_comment_count')
sns.boxplot(x=data['video_comment_count']);

# %%
plt.figure(figsize=(5,3))
sns.histplot(data['video_comment_count'], bins=range(0,(3001),100))
plt.title('Video comment count histogram');

# %% [markdown]
# Again, the vast majority of videos are grouped at the bottom of the range of values for video comment count. Most videos have fewer than 100 comments. The distribution is very right-skewed.

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">video_share_count**

# %%
#Create a boxplot to visualize distribution of `video_share_count`
plt.figure(figsize=(5,1))
plt.title('video_share_count')
sns.boxplot(x=data['video_share_count']);

# %%
plt.figure(figsize=(5,3))
sns.histplot(data['video_share_count'], bins=range(0,(270001),10000))
plt.title('Video share count histogram');

# %% [markdown]
# The overwhelming majority of videos had fewer than 10,000 shares. The distribution is very skewed to the right.

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">video_download_count**

# %%
# Create a boxplot to visualize distribution of `video_download_count`
plt.figure(figsize=(5,1))
plt.title('video_download_count')
sns.boxplot(x=data['video_download_count']);

# %%
plt.figure(figsize=(5,3))
sns.histplot(data['video_download_count'], bins=range(0,(15001),500))
plt.title('Video download count histogram');

# %% [markdown]
# The majority of videos were downloaded fewer than 500 times, but some were downloaded over 12,000 times. Again, the data is very skewed to the right.

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">Claim status by verification status**

# %%
plt.figure(figsize=(7,4))
sns.histplot(data=data,
             x='claim_status',
             hue='verified_status',
             multiple='dodge',
             shrink=0.9)
plt.title('Claims by verification status histogram');

# %% [markdown]
# There are far fewer verified users than unverified users, but if a user *is* verified, they are much more likely to post opinions.

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">Claim status by author ban status**

# %%
fig = plt.figure(figsize=(7,4))
sns.histplot(data, x='claim_status', hue='author_ban_status',
             multiple='dodge',
             hue_order=['active', 'under review', 'banned'],
             shrink=0.9,
             palette={'active':'green', 'under review':'orange', 'banned':'red'},
             alpha=0.5)
plt.title('Claim status by author ban status - counts');

# %% [markdown]
# For both claims and opinions, there are many more active authors than banned authors or authors under review; however, the proportion of active authors is far greater for opinion videos than for claim videos. Again, it seems that authors who post claim videos are more likely to come under review and/or get banned.

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">Median view counts by ban status**

# %%
ban_status_counts = data.groupby(['author_ban_status']).median(
    numeric_only=True).reset_index()

fig = plt.figure(figsize=(5,3))
sns.barplot(data=ban_status_counts,
            x='author_ban_status',
            y='video_view_count',
            order=['active', 'under review', 'banned'],
            palette={'active':'green', 'under review':'orange', 'banned':'red'},
            alpha=0.5)
plt.title('Median view count by ban status');

# %% [markdown]
# The median view counts for non-active authors are many times greater than the median view count for active authors. Since you know that non-active authors are more likely to post claims, and that videos by non-active authors get far more views on aggregate than videos by active authors, then `video_view_count` might be a good indicator of claim status.
#
# Indeed, a quick check of the median view count by claim status bears out this assessment:

# %%
data.groupby('claim_status')['video_view_count'].median()
# Out:
# claim_status
# claim      501555.0
# opinion      4953.0
# Name: video_view_count, dtype: float64

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">Total views by claim status**

# %%
fig = plt.figure(figsize=(3,3))
plt.pie(data.groupby('claim_status')['video_view_count'].sum(), labels=['claim', 'opinion'])
plt.title('Total views by video claim status');

# %% [markdown]
# The overall view count is dominated by claim videos even though there are roughly the same number of each video in the dataset.

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#34495E;">Determine outliers**
#
#
# In predictive modeling, outliers may introduce bias or signify data recording issues. For instance, in predicting TikTok video view count, videos with extreme views could bias our model. However, our analysis suggests these extremes align with social media's viral nature, where a tiny fraction of videos gain massive engagement.
#
# Our project aims to predict if a video is a claim or opinion, a status correlated with engagement level. It's vital, thus, to understand the extent of outliers in our data. Defining an outlier often relies on the project specifics and domain expertise. Commonly, outliers in a normally distributed set are those exceeding 1.5 * Interquartile Range (IQR) above the 3rd quartile.
#
# In our TikTok data, count variables are heavily right-skewed rather than normally distributed. A modified outlier threshold can be set using the median value for each variable, added to 1.5 * IQR, which results in a lower threshold than using the 3rd quartile

# %%
count_cols = ['video_view_count',
              'video_like_count',
              'video_share_count',
              'video_download_count',
              'video_comment_count',
              ]

for column in count_cols:
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    median = data[column].median()
    outlier_threshold = median + 1.5*iqr

    # Count the number of values that exceed the outlier threshold
    outlier_count = (data[column] > outlier_threshold).sum()
    print(f'Number of outliers, {column}:', outlier_count)
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %% [markdown]
# #### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#EE4B2B;">Scatterplot**

# %%
# Create a scatterplot of `video_like_count` versus `video_comment_count` according to 'claim_status'
sns.scatterplot(x=data["video_view_count"], y=data["video_like_count"],
                hue=data["claim_status"], s=10, alpha=.3)
plt.show()

# %%
# Create a scatterplot of `video_like_count` versus `video_comment_count` for opinions only
opinion = data[data['claim_status']=='opinion']
sns.scatterplot(x=opinion["video_view_count"], y=opinion["video_like_count"],
                 s=10, alpha=.3)
plt.show()

# %% [markdown]
# ### **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#2ECC71;"><span style="color:#2ECC71;">P</span><span style="color:#FFC300;">A</span><span style="color:#3498DB;">C</span><span style="color:#9B59B6;">E</span></span> : </span><span style="color:#9B59B6;">Execute**</span>

# %% [markdown]
# ## **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#34495E;">Results and evaluation**
#
# Through this exploratory data analysis, I have:
#
# * Analyzed the spread, frequency, mean, and median values of various features in the dataset.
# * Identified outliers, and considered strategies for dealing with these.
# * Checked for missing data, and ensured that our dataset is clean and ready for further analysis.
# * Explored relationships between the 'claim_status' variable and other variables in the dataset.
#
# Based on this analysis, I have generated new questions and insights:
#
# * It would be beneficial to further investigate the unique characteristics that differentiate 'claim' videos from 'opinion' videos. Are there patterns or specific features that are more prevalent in one category versus the other?
# * I want to dig deeper and consider if there are other variables not yet considered that could provide further insight or understanding about our dataset.
#
# What our client might find of interest is:
#
# * The preliminary insights we have gathered regarding which data might be predictive of 'claim_status'. For instance, the engagement metrics like view count, like count, share count, download count, and comment count are showing correlation with the claim status of the video. This can be the foundation for building a predictive model to classify videos as 'claims' or 'opinions'.
#
# * It's also important for the client to understand that there are outliers in our data, and the strategy we adopt to handle these outliers can influence the performance of any future models. Our decision to keep, delete or adjust these outliers will be data-specific and based on our understanding of the dataset and the project goals.

# %% [markdown]
# ## **<span style="font-family:'Courier New', monospace; font-weight:bold; color:#34495E;">Conclusion**
#
# Exploratory Data Analysis is important because...
#
# * EDA is akin to a preliminary investigation, enables a deeper dive into the dataset. It aids in understanding the data's characteristics, identifying any anomalies such as outliers, handling missing values, and thus prepping the data for future modeling. It provides a robust foundation for any subsequent data processing tasks and predictive modeling, enhancing the accuracy of the outcomes.
#
# Through visualizations, I was able to comprehend...
#
# * The need for important decisions regarding data preprocessing prior to building a predictive model. Visual representations clarified the existence of outliers, duplicate entries, and missing data. These visual insights will guide us in determining the most suitable techniques to handle these issues, thereby ensuring that our dataset is appropriately prepared for model development.
